# %% [markdown]
# # BANKING77 intent classification
#
# This notebook inspects the data and the reproducible outputs created by `../run_pipeline.py`. The reusable modelling code lives in `../src/banking_intent/`.

# %%
from pathlib import Path
import json
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
train = pd.read_csv(ROOT / 'data/raw/train.csv')
test = pd.read_csv(ROOT / 'data/raw/test.csv')
print(train.shape, test.shape, train['category'].nunique())
train.head()

# %% [markdown]
# ## Reproduce the full experiment
#
# The pipeline keeps the official test split untouched until model selection and the handoff threshold have been fixed on a validation split.

# %%
# This downloads all-MiniLM-L6-v2 on first use.
# %run ../run_pipeline.py

# %%
metrics_path = ROOT / 'reports/metrics.json'
metrics = json.loads(metrics_path.read_text())
metrics

# %%
comparison = pd.read_csv(ROOT / 'reports/model_comparison.csv')
comparison

# %%
errors = pd.read_csv(ROOT / 'reports/misclassified_examples.csv')
errors[['text', 'category', 'predicted_intent', 'confidence']].head(10)
